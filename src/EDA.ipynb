# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("../data/cleaned_data/cleaned.csv")

# %% [markdown]
# ## Data Summary

# %%
print("Snapshot of first 5 rows of data:")
df.head(5)
# Out:
# Snapshot of first 5 rows of data:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob ...  \
# 0       0    1   18        1        1        0     4     4     4     0 ...
# 1       0    1   17        1        1        1     1     1     4     1 ...
# 2       0    1   15        1        0        1     1     1     4     1 ...
# 3       0    1   15        1        1        1     4     2     3     2 ...
# 4       0    1   16        1        1        1     3     3     1     1 ...
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         6   5   6   6
# 1       5         3      3     1     1       3         4   5   5   6
# 2       4         3      2     2     3       3        10   7   8  10
# 3       3         2      2     1     1       5         2  15  14  15
# 4       4         3      2     1     2       5         4   6  10  10
#
# [5 rows x 33 columns]

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 382
# Number of columns: 33

# %%
print("Number of Nulls in each variable")
df.isnull().sum()
# Out:
# Number of Nulls in each variable
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
print("Statistical summary for rating variables:")
df.iloc[:,23:29].describe()
# Out:
# Statistical summary for rating variables:
#            famrel    freetime       goout        Dalc        Walc      health
# count  382.000000  382.000000  382.000000  382.000000  382.000000  382.000000
# mean     3.939791    3.222513    3.112565    1.473822    2.280105    3.578534
# std      0.921620    0.988233    1.131927    0.886229    1.282866    1.400360
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    3.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000

# %%
df.iloc[:,:22].describe()
# Out:
#            school         sex         age     address     famsize     Pstatus  \
# count  382.000000  382.000000  382.000000  382.000000  382.000000  382.000000
# mean     0.104712    0.518325   16.586387    0.787958    0.727749    0.900524
# std      0.306584    0.500319    1.173470    0.409290    0.445702    0.299693
# min      0.000000    0.000000   15.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   16.000000    1.000000    0.000000    1.000000
# 50%      0.000000    1.000000   17.000000    1.000000    1.000000    1.000000
# 75%      0.000000    1.000000   17.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000   22.000000    1.000000    1.000000    1.000000
#
#              Medu        Fedu        Mjob        Fjob     ...      traveltime  \
# count  382.000000  382.000000  382.000000  382.000000     ...      382.000000
# mean     2.806283    2.565445    1.678010    1.413613     ...        1.442408
# std      1.086381    1.096240    1.245881    0.864356     ...        0.695378
# min      0.000000    0.000000    0.000000    0.000000     ...        1.000000
# 25%      2.000000    2.000000    1.000000    1.000000     ...        1.000000
# 50%      3.000000    3.000000    1.000000    1.000000     ...        1.000000
# 75%      4.000000    4.000000    2.000000    2.000000     ...        2.000000
# max      4.000000    4.000000    4.000000    4.000000     ...        4.000000
#
#         studytime    failures   schoolsup      famsup        paid  activities  \
# count  382.000000  382.000000  382.000000  382.000000  382.000000  382.000000
# mean     2.034031    0.290576    0.133508    0.623037    0.463351    0.526178
# std      0.845798    0.729481    0.340569    0.485261    0.499309    0.499969
# min      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      2.000000    0.000000    0.000000    1.000000    0.000000    1.000000
# 75%      2.000000    0.000000    0.000000    1.000000    1.000000    1.000000
# max      4.000000    3.000000    1.000000    1.000000    1.000000    1.000000
#
#           nursery      higher    internet
# count  382.000000  382.000000  382.000000
# mean     0.811518    0.952880    0.848168
# std      0.391609    0.212174    0.359329
# min      0.000000    0.000000    0.000000
# 25%      1.000000    1.000000    1.000000
# 50%      1.000000    1.000000    1.000000
# 75%      1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000
#
# [8 rows x 22 columns]

# %%
print("Statistical summary for other numeric variables:")
df.iloc[:,30:33].describe()
# Out:
# Statistical summary for other numeric variables:
#                G1          G2          G3
# count  382.000000  382.000000  382.000000
# mean    10.861257   10.712042   10.387435
# std      3.349167    3.832560    4.687242
# min      3.000000    0.000000    0.000000
# 25%      8.000000    8.250000    8.000000
# 50%     10.500000   11.000000   11.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   20.000000

# %% [markdown]
# ## Visualized Observations

# %% [markdown]
# **Relationships among grade for different tests**

# %%
sns.pairplot(df, vars=["G1","G2","G3"], diag_kind='kde')
plt.savefig("../graphs/grades_pairplot.png")

# %% [markdown]
# **Visualize difference of gender on final grade G3**

# %%
gender = sns.boxplot(x = "sex", y = "G3", data = df)
gender.set_xticklabels(["Male", "Female"])
plt.title("Final grade between male and female")
plt.xlabel("")
plt.ylabel("final grade")
plt.savefig("../graphs/gender_grade.png")

# %% [markdown]
# **Visualize difference of weekly study time on final grade G3**

# %%
studytime = sns.boxplot(x = "studytime", y = "G3", data = df)
study_label = ["<2hours", "2-5hours", "5-10hours", ">10hours"]
plt.title("Final grades and weekly study time")
plt.xlabel("study time")
studytime.set_xticklabels(study_label)
plt.ylabel("final grade")
plt.savefig("../graphs/studytime_grade.png")

# %% [markdown]
# **Visualize whether student decide to go to higher education has any relationship with final grade G3**

# %%
higher = sns.boxplot(x = "higher", y = "G3", data = df)
higher_label = ["no", "yes"]
plt.title("Final grades and whether students decide to pursue higher education")
plt.xlabel("")
higher.set_xticklabels(higher_label)
plt.ylabel("final grade")
plt.savefig("../graphs/higheredu_grade.png")
